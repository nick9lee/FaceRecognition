# %% [markdown]
# # Method 1
#
# ## this is it

# %%
import cv2
import os
import random

# set the path to the FDDB dataset directory
data_dir = ''

# read the list of image paths from the FDDB dataset
image_list_path = os.path.join(data_dir, 'FDDB-folds', 'all.txt')
with open(image_list_path, 'r') as f:
    image_paths = [os.path.join(data_dir, line.strip() + '.jpg') for line in f]

# load the annotations for the images
annotations_path = os.path.join(data_dir, 'FDDB-folds', 'FDDB-all-fold-ellipseList.txt')
with open(annotations_path, 'r') as f:
    annotations = [line.strip().split()[2:] for line in f]

# display a random subset of the images and annotations
num_images_to_display = 10
for i in range(num_images_to_display):
    # choose a random image and annotation
    image_path = random.choice(image_paths)
    annotation = annotations[image_paths.index(image_path)]
    
    # load the image and draw the face bounding box
    image = cv2.imread(image_path)
    cv2.ellipse(image, tuple(map(int, annotation[:2])), tuple(map(int, annotation[2:])), 0, 0, 360, (0, 255, 0), 2)
    
    # display the image
    cv2.imshow('image', image)
    cv2.waitKey(0)
    
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/5m/5pzld6bj35vgyps_t9tb39z80000gn/T/ipykernel_71024/1989050778.py in <module>
#       9 # read the list of image paths from the FDDB dataset
#      10 image_list_path = os.path.join(data_dir, 'FDDB-folds', 'all.txt')
# ---> 11 with open(image_list_path, 'r') as f:
#      12     image_paths = [os.path.join(data_dir, 'originalPics', line.strip() + '.jpg') for line in f]
#      13
#
# FileNotFoundError: [Errno 2] No such file or directory: './originalPics/FDDB-folds/all.txt'
